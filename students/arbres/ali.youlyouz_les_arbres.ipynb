# %% [markdown]
# # ALI YOULYOUZ

# %%
import os
os.getcwd()
# Out:
# '/Users/alexis/amcp/XEmines/students/arbres'

# %%
# os.chdir("C:\\Users\\Toshiba\\bases_donnees")
import pandas as pd

# %%
df1 = pd.read_csv('les-arbres.csv',sep=';',error_bad_lines=False)
# Out:
# b'Skipping line 1916: expected 17 fields, saw 18\n'

# %%
df2=pd.read_csv('arrondissements.csv',sep=';',error_bad_lines=False)

# %%
df1.describe()
# Out:
#              IDBASE  NUMERO  CIRCONFERENCEENCM    HAUTEUR (m)    REMARQUABLE
# count  2.003320e+05     0.0      200332.000000  200332.000000  137203.000000
# mean   3.871040e+05     NaN          83.377988      13.108235       0.001341
# std    5.454652e+05     NaN         672.864029    1970.258098       0.036596
# min    9.987400e+04     NaN           0.000000       0.000000       0.000000
# 25%    1.558788e+05     NaN          30.000000       5.000000       0.000000
# 50%    2.210865e+05     NaN          70.000000       8.000000       0.000000
# 75%    2.741462e+05     NaN         115.000000      12.000000       0.000000
# max    2.024745e+06     NaN      250255.000000  881818.000000       1.000000

# %%
df2.describe
# Out:
# <bound method NDFrame.describe of     C_ARINSEE        L_AR       SURFACE     PERIMETRE  OBJECTID      LONGUEUR
# 0       75102   2ème Ardt  9.911537e+05   4554.104360         2   4553.938764
# 1       75103   3ème Ardt  1.170883e+06   4519.263648         3   4519.071982
# 2       75112  12ème Ardt  1.631478e+07  24089.666298        12  24088.038922
# 3       75101    1er Ardt  1.824613e+06   6054.936862         1   6054.680862
# 4       75104   4ème Ardt  1.600586e+06   5420.908434         4   5420.636779
# 5       75108   8ème Ardt  3.880036e+06   7880.533268         8   7880.260661
# 6       75114  14ème Ardt  5.614877e+06  10317.483310        14  10316.720258
# 7       75119  19ème Ardt  6.792651e+06  11253.182479        19  11252.943229
# 8       75120  20ème Ardt  5.983446e+06  10704.940486        20  10704.483774
# 9       75106   6ème Ardt  2.153096e+06   6483.686786         6   6483.324560
# 10      75109   9ème Ardt  2.178303e+06   6471.588290         9   6471.389144
# 11      75117  17ème Ardt  5.668835e+06  10775.579516        17  10775.348915
# 12      75115  15ème Ardt  8.494994e+06  13678.798315        15  13677.923661
# 13      75105   5ème Ardt  2.539375e+06   6239.195396         5   6238.823408
# 14      75107   7ème Ardt  4.090057e+06   8099.424883         7   8099.033151
# 15      75110  10ème Ardt  2.891739e+06   6739.375055        10   6739.168359
# 16      75111  11ème Ardt  3.665442e+06   8282.011886        11   8281.635288
# 17      75113  13ème Ardt  7.149311e+06  11546.546526        13  11545.686986
# 18      75116  16ème Ardt  1.637254e+07  17416.109657        16  17415.326726
# 19      75118  18ème Ardt  5.996051e+06   9916.464176        18   9916.303827>

# %%
df1.dtypes
# Out:
# IDBASE                float64
# TYPEEMPLACEMENT        object
# DOMANIALITE            object
# ARRONDISSEMENT         object
# COMPLEMENTADRESSE      object
# NUMERO                float64
# LIEU / ADRESSE         object
# IDEMPLACEMENT          object
# LIBELLEFRANCAIS        object
# GENRE                  object
# ESPECE                 object
# VARIETEOUCULTIVAR      object
# CIRCONFERENCEENCM     float64
# HAUTEUR (m)           float64
# STADEDEVELOPPEMENT     object
# REMARQUABLE           float64
# geo_point_2d           object
# dtype: object

# %% [markdown]
# # Exploration

# %% [markdown]
# ## Statistiques des variables numériques

# %%
df1.NUMERO.describe()
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: NUMERO, dtype: float64

# %%
df1.CIRCONFERENCEENCM.describe()
# Out:
# count    200332.000000
# mean         83.377988
# std         672.864029
# min           0.000000
# 25%          30.000000
# 50%          70.000000
# 75%         115.000000
# max      250255.000000
# Name: CIRCONFERENCEENCM, dtype: float64

# %%
df1['HAUTEUR (m)'].describe()
# Out:
# count    200332.000000
# mean         13.108235
# std        1970.258098
# min           0.000000
# 25%           5.000000
# 50%           8.000000
# 75%          12.000000
# max      881818.000000
# Name: HAUTEUR (m), dtype: float64

# %%
df1.REMARQUABLE.describe()
# Out:
# count    137203.000000
# mean          0.001341
# std           0.036596
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: REMARQUABLE, dtype: float64

# %% [markdown]
# ## Le nombre d'occurences

# %%
df1.TYPEEMPLACEMENT.value_counts()
# Out:
# Arbre    200332
# Name: TYPEEMPLACEMENT, dtype: int64

# %%
df1['DOMANIALITE'].value_counts()
# Out:
# Alignement      105061
# Jardin           46329
# CIMETIERE        31933
# DASCO             6429
# PERIPHERIQUE      5327
# DJS               3901
# DFPE              1326
# DAC                 21
# DASES                4
# Name: DOMANIALITE, dtype: int64

# %%
df1.ESPECE.value_counts()
# Out:
# x hispanica                     36464
# hippocastanum                   20063
# japonica                        11823
# n. sp.                           9074
# tomentosa                        8992
# pseudoplatanus                   7432
# platanoides                      6299
# nigra                            4947
# x europaea                       4707
# x carnea                         4417
# australis                        4121
# cordata                          3845
# excelsior                        3809
# occidentalis                     3464
# betulus                          3463
# colurna                          3381
# calleryana                       3125
# platyphyllos                     2918
# orientalis                       2756
# serrulata                        2401
# pseudoacacia                     2299
# baccata                          2010
# sylvatica                        1935
# campestre                        1524
# pendula                          1458
# alba                             1314
# nigra subsp. nigra               1222
# robur                            1217
# tulipifera                       1135
# sinensis                         1100
#                                 ...
# szechuanica var. tibetica           1
# cissifolium                         1
# suber subsp. Occidentalis           1
# ithaburensis var. macrolepis        1
# minor var. vulgaris                 1
# copallina                           1
# pseudocamellia                      1
# glaucus                             1
# muehlenbergii                       1
# americanum                          1
# vestita                             1
# x flaccida                          1
# rhytidophyllum                      1
# vilmorinii                          1
# falcata                             1
# lophantha                           1
# x macrantha                         1
# baccata var. mandshurica            1
# koyamai                             1
# x rehderiana                        1
# oliverianum                         1
# x chinensis                         1
# x persimilis                        1
# monogyna var. monogyna              1
# koraiensis                          1
# schrenkiana                         1
# rotundifolia var. aboriginum        1
# x coriaceum                         1
# macrophyllum                        1
# fruticosa                           1
# Name: ESPECE, Length: 540, dtype: int64

# %% [markdown]
# .............

# %%
df1.head()
# Out:
#      IDBASE TYPEEMPLACEMENT DOMANIALITE   ARRONDISSEMENT COMPLEMENTADRESSE  \
# 0  232702.0           Arbre  Alignement  PARIS 11E ARRDT               NaN
# 1  235862.0           Arbre  Alignement  PARIS 18E ARRDT               NaN
# 2  236391.0           Arbre  Alignement  PARIS 15E ARRDT                27
# 3  241122.0           Arbre  Alignement  PARIS 14E ARRDT               NaN
# 4   99927.0           Arbre      Jardin  PARIS 16E ARRDT               NaN
#
#    NUMERO                      LIEU / ADRESSE IDEMPLACEMENT  \
# 0     NaN           BOULEVARD DE MENILMONTANT     000602002
# 1     NaN  AVENUE DE LA PORTE DE CLIGNANCOURT     000303007
# 2     NaN                 BOULEVARD GARIBALDI     000101024
# 3     NaN                        RUE SARRETTE     000501003
# 4     NaN                  JARDIN DU RANELAGH      00030007
#
#         LIBELLEFRANCAIS    GENRE       ESPECE VARIETEOUCULTIVAR  \
# 0               Sophora  Sophora     japonica               NaN
# 1               Tilleul    Tilia    tomentosa               NaN
# 2  Noisetier de Byzance  Corylus      colurna               NaN
# 3               Tilleul    Tilia    tomentosa               NaN
# 4                Erable     Acer  platanoides      'Schwedleri'
#
#    CIRCONFERENCEENCM  HAUTEUR (m) STADEDEVELOPPEMENT  REMARQUABLE  \
# 0               55.0          5.0                 JA          0.0
# 1               60.0         10.0                 JA          NaN
# 2               60.0         10.0                 JA          NaN
# 3              155.0         12.0                  A          0.0
# 4              125.0          0.0                NaN          NaN
#
#                    geo_point_2d
# 0  48.8652353853, 2.38481800435
# 1  48.8999949231, 2.34379810146
# 2  48.8470727044, 2.30470921442
# 3  48.8259993388, 2.32878574525
# 4   48.858836461, 2.26870442691

# %% [markdown]
# ## Visualisation

# %%
import matplotlib.pyplot as plt
plt.plot(df1.CIRCONFERENCEENCM)
plt.show()

# %%
plt.plot(df1['HAUTEUR (m)'])
plt.show()

# %%
plt.plot(df1['NUMERO'])
plt.show()

# %%
plt.plot(df1['REMARQUABLE'])
plt.show()

# %% [markdown]
# ## elimination des valeurs aberrantes

# %%
df1=df1[df1.CIRCONFERENCEENCM<=500]

# %%
df1=df1[df1['HAUTEUR (m)']<=100]

# %% [markdown]
# # 3. nature des arbres par arrondissement

# %% [markdown]
# ## nombre d'arbres par arrondissement

# %%
df1['ARRONDISSEMENT'].value_counts()
# Out:
# PARIS 15E ARRDT      17144
# PARIS 13E ARRDT      16690
# PARIS 16E ARRDT      16388
# PARIS 20E ARRDT      15337
# PARIS 19E ARRDT      13699
# PARIS 12E ARRDT      12578
# SEINE-SAINT-DENIS    11573
# BOIS DE VINCENNES    11496
# PARIS 14E ARRDT      11408
# PARIS 17E ARRDT      10753
# PARIS 18E ARRDT      10012
# PARIS 7E ARRDT        8623
# VAL-DE-MARNE          7576
# PARIS 8E ARRDT        7238
# PARIS 11E ARRDT       5661
# HAUTS-DE-SEINE        5299
# BOIS DE BOULOGNE      3981
# PARIS 10E ARRDT       3384
# PARIS 4E ARRDT        2737
# PARIS 5E ARRDT        2393
# PARIS 6E ARRDT        1760
# PARIS 1ER ARRDT       1410
# PARIS 3E ARRDT        1209
# PARIS 9E ARRDT        1167
# PARIS 2E ARRDT         547
# Name: ARRONDISSEMENT, dtype: int64

# %% [markdown]
# ## nombre d'arbres par espéces

# %%
df1['ESPECE'].value_counts()
# Out:
# x hispanica                     36381
# hippocastanum                   20043
# japonica                        11809
# n. sp.                           9066
# tomentosa                        8964
# pseudoplatanus                   7429
# platanoides                      6294
# nigra                            4944
# x europaea                       4704
# x carnea                         4415
# australis                        4106
# cordata                          3843
# excelsior                        3808
# betulus                          3462
# occidentalis                     3432
# colurna                          3378
# calleryana                       3124
# platyphyllos                     2916
# orientalis                       2750
# serrulata                        2401
# pseudoacacia                     2297
# baccata                          2010
# sylvatica                        1932
# campestre                        1524
# pendula                          1458
# alba                             1313
# nigra subsp. nigra               1222
# robur                            1215
# tulipifera                       1135
# sinensis                         1099
#                                 ...
# szechuanica var. tibetica           1
# cissifolium                         1
# suber subsp. Occidentalis           1
# ithaburensis var. macrolepis        1
# minor var. vulgaris                 1
# copallina                           1
# pseudocamellia                      1
# glaucus                             1
# muehlenbergii                       1
# americanum                          1
# vestita                             1
# x flaccida                          1
# rhytidophyllum                      1
# vilmorinii                          1
# falcata                             1
# lophantha                           1
# x macrantha                         1
# baccata var. mandshurica            1
# koyamai                             1
# x rehderiana                        1
# oliverianum                         1
# x chinensis                         1
# x persimilis                        1
# monogyna var. monogyna              1
# koraiensis                          1
# schrenkiana                         1
# rotundifolia var. aboriginum        1
# x coriaceum                         1
# macrophyllum                        1
# fruticosa                           1
# Name: ESPECE, Length: 540, dtype: int64

# %% [markdown]
# ## nombre d'arbres par damanialité

# %%
df1['DOMANIALITE'].value_counts()
# Out:
# Alignement      104892
# Jardin           46269
# CIMETIERE        31925
# DASCO             6421
# PERIPHERIQUE      5325
# DJS               3882
# DFPE              1323
# DAC                 21
# DASES                4
# Name: DOMANIALITE, dtype: int64

# %% [markdown]
# ## nombre de variétés d'arbres par arrondissements

# %%
L=[]
for i in range(0,len(df1['ARRONDISSEMENT'].value_counts())):
    data=df1[df1.ARRONDISSEMENT==df1['ARRONDISSEMENT'].value_counts().index[i]]
    L.append(len(data['VARIETEOUCULTIVAR'].value_counts()))
import numpy as np
import pandas as pd
table = pd.DataFrame(np.array(L), index = np.array(df1['ARRONDISSEMENT'].value_counts().index))
table
# Out:
#                      0
# PARIS 15E ARRDT    147
# PARIS 13E ARRDT    139
# PARIS 16E ARRDT    186
# PARIS 20E ARRDT    151
# PARIS 19E ARRDT    124
# PARIS 12E ARRDT     96
# SEINE-SAINT-DENIS   54
# BOIS DE VINCENNES   49
# PARIS 14E ARRDT    130
# PARIS 17E ARRDT    157
# PARIS 18E ARRDT    184
# PARIS 7E ARRDT      48
# VAL-DE-MARNE        44
# PARIS 8E ARRDT      76
# PARIS 11E ARRDT     77
# HAUTS-DE-SEINE      20
# BOIS DE BOULOGNE    26
# PARIS 10E ARRDT     79
# PARIS 4E ARRDT      57
# PARIS 5E ARRDT      59
# PARIS 6E ARRDT      16
# PARIS 1ER ARRDT     19
# PARIS 3E ARRDT      27
# PARIS 9E ARRDT      45
# PARIS 2E ARRDT      27

# %% [markdown]
# ## nombre de variétés d'arbres par espèces

# %%
L=[]
for i in range(0,len(df1['ESPECE'].value_counts())):
    data=df1[df1.ARRONDISSEMENT==df1['ESPECE'].value_counts().index[i]]
    L.append(len(data['VARIETEOUCULTIVAR'].value_counts()))
import numpy as np
import pandas as pd
table = pd.DataFrame(np.array(L), index = np.array(df1['ESPECE'].value_counts().index))
table
# Out:
#                               0
# x hispanica                   0
# hippocastanum                 0
# japonica                      0
# n. sp.                        0
# tomentosa                     0
# pseudoplatanus                0
# platanoides                   0
# nigra                         0
# x europaea                    0
# x carnea                      0
# australis                     0
# cordata                       0
# excelsior                     0
# betulus                       0
# occidentalis                  0
# colurna                       0
# calleryana                    0
# platyphyllos                  0
# orientalis                    0
# serrulata                     0
# pseudoacacia                  0
# baccata                       0
# sylvatica                     0
# campestre                     0
# pendula                       0
# alba                          0
# nigra subsp. nigra            0
# robur                         0
# tulipifera                    0
# sinensis                      0
# ...                          ..
# szechuanica var. tibetica     0
# cissifolium                   0
# suber subsp. Occidentalis     0
# ithaburensis var. macrolepis  0
# minor var. vulgaris           0
# copallina                     0
# pseudocamellia                0
# glaucus                       0
# muehlenbergii                 0
# americanum                    0
# vestita                       0
# x flaccida                    0
# rhytidophyllum                0
# vilmorinii                    0
# falcata                       0
# lophantha                     0
# x macrantha                   0
# baccata var. mandshurica      0
# koyamai                       0
# x rehderiana                  0
# oliverianum                   0
# x chinensis                   0
# x persimilis                  0
# monogyna var. monogyna        0
# koraiensis                    0
# schrenkiana                   0
# rotundifolia var. aboriginum  0
# x coriaceum                   0
# macrophyllum                  0
# fruticosa                     0
#
# [540 rows x 1 columns]

# %% [markdown]
# ## nombre de variétés d'arbres par domanialité

# %%
L=[]
for i in range(0,len(df1['DOMANIALITE'].value_counts())):
    data=df1[df1.ARRONDISSEMENT==df1['DOMANIALITE'].value_counts().index[i]]
    L.append(len(data['VARIETEOUCULTIVAR'].value_counts()))
import numpy as np
import pandas as pd
table = pd.DataFrame(np.array(L), index = np.array(df1['DOMANIALITE'].value_counts().index))
table
# Out:
#               0
# Alignement    0
# Jardin        0
# CIMETIERE     0
# DASCO         0
# PERIPHERIQUE  0
# DJS           0
# DFPE          0
# DAC           0
# DASES         0

# %% [markdown]
# ## statistiques de la hauteur par arrondissement

# %%
import numpy as np
import pandas as pd
A=pd.DataFrame(data=None, columns=np.array(df1['HAUTEUR (m)'].describe().index))
for i in range(0,len(df1['ARRONDISSEMENT'].value_counts())):
    data=df1[df1.ARRONDISSEMENT==df1['ARRONDISSEMENT'].value_counts().index[i]]
    M=data['HAUTEUR (m)'].describe()
    L=[i for i in M]
    N=np.transpose(L, axes=None)
    A.loc[len(A)]=N
A.index=np.array(df1['ARRONDISSEMENT'].value_counts().index)
A
# Out:
#                      count       mean       std  min  25%   50%   75%    max
# PARIS 15E ARRDT    17144.0   6.320287  5.679558  0.0  0.0   6.0  10.0   88.0
# PARIS 13E ARRDT    16690.0   8.568364  9.582946  0.0  4.0   8.0  12.0  100.0
# PARIS 16E ARRDT    16388.0  10.067305  5.981332  0.0  5.0  10.0  14.0  100.0
# PARIS 20E ARRDT    15337.0   8.587338  5.958621  0.0  5.0   8.0  12.0   70.0
# PARIS 19E ARRDT    13699.0   8.540550  7.289160  0.0  1.0   8.0  15.0   90.0
# PARIS 12E ARRDT    12578.0   9.020592  5.404712  0.0  5.0  10.0  10.0  100.0
# SEINE-SAINT-DENIS  11573.0   4.576687  6.085881  0.0  0.0   0.0   8.0   78.0
# BOIS DE VINCENNES  11496.0   8.423278  7.657014  0.0  0.0   8.0  14.0  100.0
# PARIS 14E ARRDT    11408.0   9.261834  4.645426  0.0  6.0   8.0  12.0   68.0
# PARIS 17E ARRDT    10753.0   7.780247  5.560073  0.0  4.0   8.0  12.0   55.0
# PARIS 18E ARRDT    10012.0   8.280264  6.131721  0.0  5.0   8.0  12.0   97.0
# PARIS 7E ARRDT      8623.0  11.447756  5.432791  0.0  8.0  10.0  15.0   89.0
# VAL-DE-MARNE        7576.0   7.248152  9.320685  0.0  0.0   3.0  15.0   98.0
# PARIS 8E ARRDT      7238.0  11.411578  5.233275  0.0  8.0  11.0  15.0   35.0
# PARIS 11E ARRDT     5661.0  10.306660  5.506912  0.0  5.0  10.0  15.0   80.0
# HAUTS-DE-SEINE      5299.0   1.520853  3.791331  0.0  0.0   0.0   0.0   20.0
# BOIS DE BOULOGNE    3981.0   8.193419  5.776992  0.0  5.0   8.0  12.0   68.0
# PARIS 10E ARRDT     3384.0  10.223109  5.985463  0.0  6.0  10.0  13.0   75.0
# PARIS 4E ARRDT      2737.0  10.356960  5.692416  0.0  5.0  10.0  15.0   65.0
# PARIS 5E ARRDT      2393.0  11.284580  6.247582  0.0  7.0  10.0  15.0   99.0
# PARIS 6E ARRDT      1760.0  11.563068  5.383370  0.0  8.0  10.0  15.0   78.0
# PARIS 1ER ARRDT     1410.0   8.635461  6.495105  0.0  5.0  10.0  10.0  100.0
# PARIS 3E ARRDT      1209.0   9.859388  4.977440  0.0  6.0   9.0  13.0   30.0
# PARIS 9E ARRDT      1167.0   9.957155  5.614996  0.0  6.0  10.0  14.0   28.0
# PARIS 2E ARRDT       547.0   9.521024  5.818769  0.0  5.0   9.0  13.0   86.0

# %% [markdown]
# ## statistiques de la hauteur par espèce

# %%
df1.dropna()
import numpy as np
import pandas as pd
A=pd.DataFrame(data=None, columns=np.array(df1['HAUTEUR (m)'].describe().index))
for i in range(0,len(df1['ESPECE'].value_counts())):
    data=df1[df1.ARRONDISSEMENT==df1['ESPECE'].value_counts().index[i]]
    M=data['HAUTEUR (m)'].describe()
    L=[i for i in M]
    N=np.transpose(L, axes=None)
    A.loc[len(A)]=N
A.index=np.array(df1['ESPECE'].value_counts().index)
A
# Out:
#                               count  mean  std  min  25%  50%  75%  max
# x hispanica                     0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# hippocastanum                   0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# japonica                        0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# n. sp.                          0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# tomentosa                       0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# pseudoplatanus                  0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# platanoides                     0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# nigra                           0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# x europaea                      0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# x carnea                        0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# australis                       0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# cordata                         0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# excelsior                       0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# betulus                         0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# occidentalis                    0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# colurna                         0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# calleryana                      0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# platyphyllos                    0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# orientalis                      0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# serrulata                       0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# pseudoacacia                    0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# baccata                         0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# sylvatica                       0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# campestre                       0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# pendula                         0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# alba                            0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# nigra subsp. nigra              0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# robur                           0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# tulipifera                      0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# sinensis                        0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                             ...   ...  ...  ...  ...  ...  ...  ...
# szechuanica var. tibetica       0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# cissifolium                     0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# suber subsp. Occidentalis       0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ithaburensis var. macrolepis    0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# minor var. vulgaris             0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# copallina                       0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# pseudocamellia                  0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# glaucus                         0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# muehlenbergii                   0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# americanum                      0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# vestita                         0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# x flaccida                      0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# rhytidophyllum                  0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# vilmorinii                      0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# falcata                         0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# lophantha                       0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# x macrantha                     0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# baccata var. mandshurica        0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# koyamai                         0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# x rehderiana                    0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# oliverianum                     0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# x chinensis                     0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# x persimilis                    0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# monogyna var. monogyna          0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# koraiensis                      0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# schrenkiana                     0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# rotundifolia var. aboriginum    0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# x coriaceum                     0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# macrophyllum                    0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# fruticosa                       0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [540 rows x 8 columns]

# %% [markdown]
# ## statistiques de la hauteur par domanialité

# %%
df1.dropna()
import numpy as np
import pandas as pd
A=pd.DataFrame(data=None, columns=np.array(df1['HAUTEUR (m)'].describe().index))
for i in range(0,len(df1['DOMANIALITE'].value_counts())):
    data=df1[df1.ARRONDISSEMENT==df1['DOMANIALITE'].value_counts().index[i]]
    M=data['HAUTEUR (m)'].describe()
    L=[i for i in M]
    N=np.transpose(L, axes=None)http://localhost:8888/notebooks/homework1.ipynb#statistiques-de-la-circonf%C3%A9rence-par-arrondissement
    A.loc[len(A)]=N
A.index=np.array(df1['DOMANIALITE'].value_counts().index)
A
# Out:
#   File "<ipython-input-33-f59eecaf1c88>", line 9
#     N=np.transpose(L, axes=None)http://localhost:8888/notebooks/homework1.ipynb#statistiques-de-la-circonf%C3%A9rence-par-arrondissement
#                                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## statistiques de la circonférence par arrondissement

# %%
df1.dropna()
import numpy as np
import pandas as pd
A=pd.DataFrame(data=None, columns=np.array(df1['CIRCONFERENCEENCM'].describe().index))
for i in range(0,len(df1['ARRONDISSEMENT'].value_counts())):
    data=df1[df1.ARRONDISSEMENT==df1['ARRONDISSEMENT'].value_counts().index[i]]
    M=data['CIRCONFERENCEENCM'].describe()
    L=[i for i in M]
    N=np.transpose(L, axes=None)
    A.loc[len(A)]=N
A.index=np.array(df1['ARRONDISSEMENT'].value_counts().index)
A
# Out:
#                      count        mean        std  min   25%   50%     75%  \
# PARIS 15E ARRDT    17144.0   69.589886  54.546147  0.0  27.0  65.0  100.00
# PARIS 13E ARRDT    16690.0   71.652606  52.661491  0.0  30.0  65.0  100.00
# PARIS 16E ARRDT    16388.0   93.596168  62.092424  0.0  50.0  80.0  120.00
# PARIS 20E ARRDT    15337.0   90.726478  59.605680  0.0  40.0  80.0  128.00
# PARIS 19E ARRDT    13699.0   90.614132  62.655144  0.0  40.0  80.0  125.00
# PARIS 12E ARRDT    12578.0   82.510733  55.893943  0.0  45.0  75.0  105.00
# SEINE-SAINT-DENIS  11573.0   50.840059  69.188382  0.0   0.0   0.0   95.00
# BOIS DE VINCENNES  11496.0   69.108299  68.921996  0.0   0.0  50.0  115.00
# PARIS 14E ARRDT    11408.0   97.393233  57.848555  2.0  50.0  90.0  130.00
# PARIS 17E ARRDT    10753.0   80.478936  57.790460  0.0  36.0  70.0  120.00
# PARIS 18E ARRDT    10012.0   79.480523  56.695937  0.0  35.0  69.0  110.00
# PARIS 7E ARRDT      8623.0   92.768410  56.378170  0.0  50.0  85.0  120.00
# VAL-DE-MARNE        7576.0   68.886616  88.355752  0.0   0.0  20.0  130.00
# PARIS 8E ARRDT      7238.0  104.210555  60.753146  0.0  60.0  97.0  134.00
# PARIS 11E ARRDT     5661.0   81.895248  49.015219  0.0  45.0  75.0  110.00
# HAUTS-DE-SEINE      5299.0   16.809775  41.465241  0.0   0.0   0.0    0.00
# BOIS DE BOULOGNE    3981.0   66.071088  56.480229  0.0  21.0  55.0  100.00
# PARIS 10E ARRDT     3384.0   83.100473  64.268065  0.0  39.0  67.0  112.00
# PARIS 4E ARRDT      2737.0   90.175374  61.030101  0.0  45.0  75.0  120.00
# PARIS 5E ARRDT      2393.0   94.070205  64.162635  0.0  45.0  85.0  130.00
# PARIS 6E ARRDT      1760.0   88.831250  59.333482  0.0  40.0  75.0  120.75
# PARIS 1ER ARRDT     1410.0   81.875177  57.094881  0.0  40.0  70.0  105.00
# PARIS 3E ARRDT      1209.0   82.332506  50.324134  0.0  48.0  74.0  103.00
# PARIS 9E ARRDT      1167.0   81.916881  51.451595  0.0  50.0  74.0  105.00
# PARIS 2E ARRDT       547.0   76.603291  50.789786  0.0  35.0  68.0  102.50
#
#                      max
# PARIS 15E ARRDT    480.0
# PARIS 13E ARRDT    430.0
# PARIS 16E ARRDT    500.0
# PARIS 20E ARRDT    500.0
# PARIS 19E ARRDT    460.0
# PARIS 12E ARRDT    482.0
# SEINE-SAINT-DENIS  330.0
# BOIS DE VINCENNES  500.0
# PARIS 14E ARRDT    458.0
# PARIS 17E ARRDT    479.0
# PARIS 18E ARRDT    480.0
# PARIS 7E ARRDT     482.0
# VAL-DE-MARNE       390.0
# PARIS 8E ARRDT     500.0
# PARIS 11E ARRDT    360.0
# HAUTS-DE-SEINE     287.0
# BOIS DE BOULOGNE   425.0
# PARIS 10E ARRDT    445.0
# PARIS 4E ARRDT     480.0
# PARIS 5E ARRDT     450.0
# PARIS 6E ARRDT     430.0
# PARIS 1ER ARRDT    340.0
# PARIS 3E ARRDT     300.0
# PARIS 9E ARRDT     480.0
# PARIS 2E ARRDT     300.0

# %% [markdown]
# ## statistiques de la circonférence par espèce

# %%
df1.dropna()
import numpy as np
import pandas as pd
A=pd.DataFrame(data=None, columns=np.array(df1['CIRCONFERENCEENCM'].describe().index))
for i in range(0,len(df1['ESPECE'].value_counts())):
    data=df1[df1.ARRONDISSEMENT==df1['ESPECE'].value_counts().index[i]]
    M=data['CIRCONFERENCEENCM'].describe()
    L=[i for i in M]
    N=np.transpose(L, axes=None)
    A.loc[len(A)]=N
A.index=np.array(df1['ESPECE'].value_counts().index)
A

# %% [markdown]
# ## statistiques de la circonférence par domanialité

# %%
df1.dropna()
import numpy as np
import pandas as pd
A=pd.DataFrame(data=None, columns=np.array(df1['CIRCONFERENCEENCM'].describe().index))
for i in range(0,len(df1['DOMANIALITE'].value_counts())):
    data=df1[df1.ARRONDISSEMENT==df1['DOMANIALITE'].value_counts().index[i]]
    M=data['CIRCONFERENCEENCM'].describe()
    L=[i for i in M]
    N=np.transpose(L, axes=None)
    A.loc[len(A)]=N
A.index=np.array(df1['DOMANIALITE'].value_counts().index)
A

# %% [markdown]
# # les arbres remarquables

# %%
df1.groupby('REMARQUABLE')['CIRCONFERENCEENCM','HAUTEUR (m)'].mean()

# %% [markdown]
# On peut alors conclure que les arbres remarquables sont celles qui sont plus longues et ont une grande circonférence

# %%
df1.groupby('REMARQUABLE')['ESPECE'].unique()
# Out:
# REMARQUABLE
# 0.0    [japonica, tomentosa, cordata, oblonga, colurn...
# 1.0    [kaki, x hispanica, orientalis, colurna, occid...
# Name: ESPECE, dtype: object

# %%
On peut gérer les valeurs manquantes de la colonne "remarquable" par remplir en:
    1: si l'arbre a une circonférence et une longueur supérieurs à la moyenne
    0 : sinon
# Out:
#      IDBASE TYPEEMPLACEMENT DOMANIALITE   ARRONDISSEMENT COMPLEMENTADRESSE  \
# 0  232702.0           Arbre  Alignement  PARIS 11E ARRDT               NaN
#
#    NUMERO             LIEU / ADRESSE IDEMPLACEMENT LIBELLEFRANCAIS    GENRE  \
# 0     NaN  BOULEVARD DE MENILMONTANT     000602002         Sophora  Sophora
#
#      ESPECE VARIETEOUCULTIVAR  CIRCONFERENCEENCM  HAUTEUR (m)  \
# 0  japonica               NaN               55.0          5.0
#
#   STADEDEVELOPPEMENT  REMARQUABLE                  geo_point_2d
# 0                 JA          0.0  48.8652353853, 2.38481800435
